# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# #1 .Data Frame
#
# ---

# %%
# create -- Dataframe -> Data ->Table
df = pd.DataFrame([1,2,3])
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
df=pd.DataFrame([1,2,3], columns=['col_Name'])
print(df)
# Out:
#    col_Name
# 0         1
# 1         2
# 2         3

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data={
    "Name":["Omkar","Yash","Atul"],
    "Age":[21,21,30],
    "Salary": [9000,4000,29000]
}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Salary
# 0  Omkar   21    9000
# 1   Yash   21    4000
# 2   Atul   30   29000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # 2.Understanding Data *frame*

# %%
df.head(2) #top rows
# Out:
#     Name  Age  Salary
# 0  Omkar   21    9000
# 1   Yash   21    4000

# %%
df.tail(2)  #Last rows
# Out:
#    Name  Age  Salary
# 1  Yash   21    4000
# 2  Atul   30   29000

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df.rename(columns={'Month Salary':'Salary'},inplace=True)

# %%
df
# Out:
#     Name  Age  Salary
# 0  Omkar   21    9000
# 1   Yash   21    4000
# 2   Atul   30   29000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
df.describe()   #Values program
# Out:
#              Age        Salary
# count   3.000000      3.000000
# mean   24.000000  14000.000000
# std     5.196152  13228.756555
# min    21.000000   4000.000000
# 25%    21.000000   6500.000000
# 50%    21.000000   9000.000000
# 75%    25.500000  19000.000000
# max    30.000000  29000.000000

# %% [markdown]
# #3 .Save and load data from CSV
#
# ---

# %%
df.to_csv('data.csv',index=False) #save data

# %%
pd.read_csv('data.csv') #Load Data #import
# Out:
#     Name  Age  Salary
# 0  Omkar   21    9000
# 1   Yash   21    4000
# 2   Atul   30   29000

# %% [markdown]
# # 4.Rows & columns = selection
#
# ---

# %%
#select column
df[["Name"]]    #Single col
# Out:
#     Name
# 0  Omkar
# 1   Yash
# 2   Atul

# %%
df[["Name","Salary"]]
# Out:
#     Name  Salary
# 0  Omkar    9000
# 1   Yash    4000
# 2   Atul   29000

# %%
#select row
df.loc[df.Name=='Omkar']
# Out:
#     Name  Age  Salary
# 0  Omkar   21    9000

# %%
df.loc[(df.Name=="Omkar") & (df['Salary'] >=6000)]
# Out:
#     Name  Age  Salary
# 0  Omkar   21    9000

# %%
#iloc -index based
df.iloc[0]
df.iloc[0:3]
# Out:
#     Name  Age  Salary
# 0  Omkar   21    9000
# 1   Yash   21    4000
# 2   Atul   30   29000

# %% [markdown]
# # 5.Filter dataframe
# ---

# %%
df_age_filter= df[df['Age'] >20]

# %%
df_age_filter
# Out:
#     Name  Age  Salary
# 0  Omkar   21    9000
# 1   Yash   21    4000
# 2   Atul   30   29000

# %%
df[(df['Age'] >= 18 ) & (df["Salary"] >= 9000)]
# Out:
#     Name  Age  Salary
# 0  Omkar   21    9000
# 2   Atul   30   29000

# %%
df.where(df["Age"] >= 25)
# Out:
#    Name   Age   Salary
# 0   NaN   NaN      NaN
# 1   NaN   NaN      NaN
# 2  Atul  30.0  29000.0

# %%
df.where(df["Age"] >= 25,other ="Not Eligible")
# Out:
#            Name           Age        Salary
# 0  Not Eligible  Not Eligible  Not Eligible
# 1  Not Eligible  Not Eligible  Not Eligible
# 2          Atul            30         29000

# %% [markdown]
# # 6.Rows and Columns -operation (ADD,UPDATE,DELETE)
#
# ---

# %%
#Add new column

df['team']=['CEO',"HR","DA"]
df
# Out:
#     Name  Age  Salary team
# 0  Omkar   21    9000  CEO
# 1   Yash   21    4000   HR
# 2   Atul   30   29000   DA

# %%
df['Bonus'] = df['Salary'] * 0.2
df
# Out:
#     Name  Age  Salary team   Bonus
# 0  Omkar   21    9000  CEO  1800.0
# 1   Yash   21    4000   HR   800.0
# 2   Atul   30   29000   DA  5800.0

# %%
#add new row
df.loc[len(df)]=['ABC',21,21000,'IT',2000]
df
# Out:
#     Name  Age  Salary team   Bonus
# 0  Omkar   21    9000  CEO  1800.0
# 1   Yash   21    4000   HR   800.0
# 2   Atul   30   29000   DA  5800.0
# 3    ABC   21   21000   IT  2000.0

# %%
len(df)
# Out:
# 4

# %%
#update valus
df.loc[0,'Salary'] = 45000
df
# Out:
#     Name  Age  Salary team   Bonus
# 0  Omkar   21   45000  CEO  1800.0
# 1   Yash   21    4000   HR   800.0
# 2   Atul   30   29000   DA  5800.0
# 3    ABC   21   21000   IT  2000.0

# %%
#update value - using column value
df.loc[df.Name =="Yash",'Salary'] =9000
df
# Out:
#     Name  Age  Salary team   Bonus
# 0  Omkar   21   45000  CEO  1800.0
# 1   Yash   21    9000   HR   800.0
# 2   Atul   30   29000   DA  5800.0
# 3    ABC   21   21000   IT  2000.0

# %%
#delete value - row and column values
df=df.drop(df[df.Name=="ABC"].index)
df  #drop row axis=0
# Out:
#     Name  Age  Salary team   Bonus
# 0  Omkar   21   45000  CEO  1800.0
# 1   Yash   21    9000   HR   800.0
# 2   Atul   30   29000   DA  5800.0

# %%
#df.drop('Bonus',axis=1,inplace=True)    #drop column

# %%
df
# Out:
#     Name  Age  Salary team   Bonus
# 0  Omkar   21   45000  CEO  1800.0
# 1   Yash   21    9000   HR   800.0
# 2   Atul   30   29000   DA  5800.0

# %%
#df.drop(['Bonus',"Team"],axis=1,inplace=True)

# %%
df
# Out:
#     Name  Age  Salary team   Bonus
# 0  Omkar   21   45000  CEO  1800.0
# 1   Yash   21    9000   HR   800.0
# 2   Atul   30   29000   DA  5800.0

# %%
# Sort
df.sort_values(by="Salary",ascending=False)      # ascending order
# Out:
#     Name  Age  Salary team   Bonus
# 0  Omkar   21   45000  CEO  1800.0
# 2   Atul   30   29000   DA  5800.0
# 1   Yash   21    9000   HR   800.0

# %% [markdown]
# #7 .Working with date values
#
# ---

# %%
df['DOJ']=['2026-01-01','2026-01-15', '2026-03-27']
df
# Out:
#     Name  Age  Salary team   Bonus         DOJ
# 0  Omkar   21   45000  CEO  1800.0  2026-01-01
# 1   Yash   21    9000   HR   800.0  2026-01-15
# 2   Atul   30   29000   DA  5800.0  2026-03-27

# %%
df['DOJ'].dtype
# Out:
# dtype('O')

# %%
import pandas as pd

data={
    "Name":["Omkar","Yash","Atul"],
    "Age":[21,21,30],
    "Salary": [9000,4000,29000]
}
df=pd.DataFrame(data)
df['team']=['CEO',"HR","DA"]
df['Bonus'] = df['Salary'] * 0.2
df['DOJ']=['2026-01-01','2026-01-15', '2026-03-27']



df['DOJ']=pd.to_datetime(df['DOJ'])

# %%
df['DOJ'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df1 =df
df
# Out:
#     Name  Age  Salary team   Bonus        DOJ
# 0  Omkar   21    9000  CEO  1800.0 2026-01-01
# 1   Yash   21    4000   HR   800.0 2026-01-15
# 2   Atul   30   29000   DA  5800.0 2026-03-27

# %%
df1['DOJ2']=['2026-01-01','2026-01-15', '2026-03-27']
df1
# Out:
#     Name  Age  Salary team   Bonus        DOJ        DOJ2
# 0  Omkar   21    9000  CEO  1800.0 2026-01-01  2026-01-01
# 1   Yash   21    4000   HR   800.0 2026-01-15  2026-01-15
# 2   Atul   30   29000   DA  5800.0 2026-03-27  2026-03-27

# %%
df1['DOJ2'].dtype
# Out:
# dtype('O')

# %%
df1['DOJ2']=pd.to_datetime(df1['DOJ2'] ,format ='%Y-%m-%d')

# %%
df1['DOJ2'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df1=df1.drop('DOJ2',axis=1)
df1
# Out:
#     Name  Age  Salary team   Bonus        DOJ
# 0  Omkar   21    9000  CEO  1800.0 2026-01-01
# 1   Yash   21    4000   HR   800.0 2026-01-15
# 2   Atul   30   29000   DA  5800.0 2026-03-27

# %%
df['DOJ'].dt.year
df['DOJ'].dt.month
df['DOJ'].dt.day
df['DOJ'].dt.day_name()
# Out:
# 0    Thursday
# 1    Thursday
# 2      Friday
# Name: DOJ, dtype: object

# %%
df['Month'] = df['DOJ'].dt.month

# %%
df['DOJ'] + pd.Timedelta(days=90)
# Out:
# 0   2026-04-01
# 1   2026-04-15
# 2   2026-06-25
# Name: DOJ, dtype: datetime64[ns]

# %% [markdown]
# #8 . Handling Missing Values

# %%
df
# Out:
#     Name  Age  Salary team   Bonus        DOJ
# 0  Omkar   21    9000  CEO  1800.0 2026-01-01
# 1   Yash   21    4000   HR   800.0 2026-01-15
# 2   Atul   30   29000   DA  5800.0 2026-03-27

# %%
df.isnull()
# Out:
#     Name    Age  Salary   team  Bonus    DOJ
# 0  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 2  False  False   False  False  False  False

# %%
import numpy as np

# %%
df.loc[df.Name=="Omkar","Salary"]==np.nan
# Out:
# 0    False
# Name: Salary, dtype: bool

# %%
df.isnull()
# Out:
#     Name    Age  Salary   team  Bonus    DOJ
# 0  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 2  False  False   False  False  False  False

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# Salary    0
# team      0
# Bonus     0
# DOJ       0
# dtype: int64

# %% [markdown]
# #9.Aggregation and Group by
#
# ---

# %%
df['Salary'].value_counts()   #frequency of value
# Out:
# Salary
# 9000     1
# 4000     1
# 29000    1
# Name: count, dtype: int64

# %%
df[df['Salary']==1].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
#Group By

df.groupby('Month')['Salary'].mean()   # aggregation based on group by
# Out:
# Month
# 1     6500.0
# 3    29000.0
# Name: Salary, dtype: float64

# %%
df.groupby('Month').agg({'Salary':'mean','Name':'count'})
# Out:
#         Salary  Name
# Month
# 1       6500.0     2
# 3      29000.0     1

# %% [markdown]
# #10.Concatenate and merge Dataframe (JOINS)

# %%
df1= pd.DataFrame({'ID':[1,2,3],'Name':['A',"B","C"]})
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2=pd.DataFrame({'ID':[1,2,2,3],'Score':[88,96,77,79]})
df2
# Out:
#    ID  Score
# 0   1     88
# 1   2     96
# 2   2     77
# 3   3     79

# %%
pd.concat([df1,df2],axis=1)    #Vertical /row level /top on top
# Out:
#     ID Name  ID  Score
# 0  1.0    A   1     88
# 1  2.0    B   2     96
# 2  3.0    C   2     77
# 3  NaN  NaN   3     79

# %%
#JOINS -----> Merge
pd.merge(df1,df2,how='inner',on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77
# 3   3    C     79

# %%
pd.merge(df1,df2,how='inner',left_on='ID',right_on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77
# 3   3    C     79
